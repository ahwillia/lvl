# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from lvl.datasets import simulate_lorenz

# %%
data, denoised, W, X = simulate_lorenz(100, 10000, latent_noise_scale=20.0, readout_weights_scale=5e-1)

# %%
X = X - np.mean(X, axis=0)
plt.plot(np.exp(denoised[:1000, :10]))

# %%
plt.imshow(data[:1000].T, aspect='auto', clim=[0, 5])

# %%
srt_data = data[:, np.lexsort(W)]

plt.imshow(srt_data[:1000].T, aspect='auto', clim=[0, 5])
