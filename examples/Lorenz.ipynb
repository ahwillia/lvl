# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from lvl.datasets import poisson_lorenz
data, rates, W, X = poisson_lorenz(100, 10000, latent_noise_scale=10.0)

# %%
plt.plot(X[:1000, :])

# %%
plt.imshow(data[:1000].T, aspect='auto', clim=[0, 2])

# %%
srt_data = data[:, np.lexsort(W)]

plt.imshow(srt_data[:1000].T, aspect='auto', clim=[0, 2])
